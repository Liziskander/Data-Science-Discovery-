# %% [markdown]
# Importing the libraries/data

# %%
import pandas as pd 
import sys
import csv
import numpy as np

csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %%
data = pd.read_csv("random_subset_data - random_subset_data.csv", engine='python', encoding='utf-8', error_bad_lines=False)
# Out:
# /tmp/ipykernel_795/3890051817.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv("random_subset_data - random_subset_data.csv", engine='python', encoding='utf-8', error_bad_lines=False)

# %% [markdown]
# We are dropping all rows that have NaN values in the full author name (FAU) and author name (AU) columns

# %%
data2=data.dropna(subset=['FAU','AU']).reset_index(drop=True)
data2
# Out:
#       Unnamed: 0      PMID                                                 TI  \
# 0            NaN  34688545  The importance of evaluating differences in HE...
# 1            NaN  35400747       Syphilis presenting as late-onset psychosis.
# 2            NaN  35199073  Out-of-hospital cardiac arrests and bystander ...
# 3            NaN  35728485  Investigation of metabolomic biomarkers for ch...
# 4            NaN  35615459  Gel-Based Autologous Chondrocyte Implantation ...
# ...          ...       ...                                                ...
# 9973         NaN  36052140  Effects of 3,4-diaminopyridine on myasthenia g...
# 9974         NaN  36041550  An international study on activated partial th...
# 9975         NaN  35615450  Switzerland's Dependence on a Diamorphine Mono...
# 9976         NaN  35167440  PBN-PVT projections modulate negative affectiv...
# 9977         NaN  35798472  Autonomic dysfunction and gastroparesis in Gul...
#
#                                                      AB  \
# 0                                                   NaN
# 1                                                   NaN
# 2     BACKGROUND & AIM: Bystander response to out-of...
# 3     BACKGROUND: Few studies have investigated mole...
# 4     Osteochondritis dissecans (OCD) is a disorder ...
# ...                                                 ...
# 9973  Background: 3,4-diaminopyridine (3,4-DAP) can ...
# 9974  BACKGROUND: Unexpected prolongation of first-l...
# 9975  In 2021, the manufacturer of diamorphine repor...
# 9976  Long-lasting negative affections dampen enthus...
# 9977  Over 25% of veterans with Gulf War illness dev...
#
#                                                      AD  \
# 0     Canadian Blood Services, Ottawa, Ontario, Cana...
# 1     Department of Psychiatry, Lokopriya Gopinath B...
# 2     Westmead Applied Research Centre, Faculty of M...
# 3     Singapore Institute for Clinical Sciences (SIC...
# 4     Deliwala Arthroscopy & Sports Injury Center, B...
# ...                                                 ...
# 9973  Neuromuscular Disorders Unit, Department of Hu...
# 9974  Department of Laboratory Medicine, Hospital Un...
# 9975  Service of Addiction Medicine, Lausanne Univer...
# 9976  Department of Anesthesiology, Shanghai General...
# 9977  Biology, Texas A&M University System, College ...
#
#                                                     AID  \
# 0     S1465-3249(21)00786-6 [pii];10.1016/j.jcyt.202...
# 1     10.4103/indianjpsychiatry.indianjpsychiatry_31...
# 2     10.1016/j.resplu.2022.100205 [doi];S2666-5204(...
# 3     S2352-3964(22)00292-4 [pii];10.1016/j.ebiom.20...
# 4                            10.1155/2022/6946860 [doi]
# ...                                                 ...
# 9973       10.3389/fphar.2022.982434 [doi];982434 [pii]
# 9974  S0009-8981(22)01282-7 [pii];10.1016/j.cca.2022...
# 9975                    10.3389/fpsyt.2022.882299 [doi]
# 9976              10.7554/eLife.68372 [doi];68372 [pii]
# 9977  jim-2021-002291 [pii];10.1136/jim-2021-002291 ...
#
#                                                      AU  \
# 0     Halpenny M;William N;Elmoazzen H;Giulivi A;Mar...
# 1                            Das S;Mukherjee S;Pathak K
# 2     Munot S;Rugel EJ;Von Huben A;Marschner S;Redfe...
# 3     Huang J;Law E;Karaman I;McCrickerd K;Fogel A;C...
# 4                                  Deliwala U;Sethia SJ
# ...                                                 ...
# 9973  Ceccanti M;Libonati L;Ruffolo G;Cifelli P;More...
# 9974  Bauca JM;Ajzner E;Cadamuro J;Hillarp A;Kristof...
# 9975         Schmitt-Koopmann C;Baud CA;Junod V;Simon O
# 9976  Zhu YB;Wang Y;Hua XX;Xu L;Liu MZ;Zhang R;Liu P...
# 9977                 Verne ZT;Fields JZ;Zhang BB;Zhou Q
#
#                                                    AUID  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4          ORCID: https://orcid.org/0000-0003-1226-4380
# ...                                                 ...
# 9973                                                NaN
# 9974                                                NaN
# 9975                                                NaN
# 9976  ORCID: https://orcid.org/0000-0002-8308-6553;O...
# 9977        ORCID: http://orcid.org/0000-0003-4165-6404
#
#                                                     FAU  \
# 0     Halpenny, Michael;William, Nishaka;Elmoazzen, ...
# 1      Das, Suhasini;Mukherjee, Sukriti;Pathak, Kangkan
# 2     Munot, Sonali;Rugel, Emily J;Von Huben, Amy;Ma...
# 3     Huang, Jian;Law, Evelyn;Karaman, Ibrahim;McCri...
# 4                   Deliwala, Ujjval;Sethia, Sumit Jain
# ...                                                 ...
# 9973  Ceccanti, Marco;Libonati, Laura;Ruffolo, Gabri...
# 9974  Bauca, Josep Miquel;Ajzner, Eva;Cadamuro, Jann...
# 9975  Schmitt-Koopmann, Caroline;Baud, Carole-Anne;J...
# 9976  Zhu, Ya-Bing;Wang, Yan;Hua, Xiao-Xiao;Xu, Ling...
# 9977  Verne, Zachary Thomas;Fields, Jeremy Z;Zhang, ...
#
#      Does COIS include a conflict? (0=no conflict, 1=conflict)  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 9973                                                NaN
# 9974                                                NaN
# 9975                                                NaN
# 9976                                                NaN
# 9977                                                NaN
#
#                                                    COIS         DEP  \
# 0     Declaration of Competing Interest The authors ...  20211028.0
# 1                   There are no conflicts of interest.  20220121.0
# 2     The authors declare that they have no known co...  20220206.0
# 3     Declaration of interests The authors disclose ...  20220618.0
# 4     The authors declare no conflict of interest fo...  20220516.0
# ...                                                 ...         ...
# 9973  The authors declare that the research was cond...  20220816.0
# 9974  Declaration of Competing Interest The authors ...  20220827.0
# 9975  The authors declare that the research was cond...  20220509.0
# 9976  YZ, YW, XH, LX, ML, RZ, PL, JL, LZ, DM No comp...  20220215.0
# 9977                Competing interests: None declared.  20220707.0
#
#                 DP                                                 JT  \
# 0         2022 Mar                                        Cytotherapy
# 1     2022 Jan-Feb                       Indian journal of psychiatry
# 2         2022 Mar                                 Resuscitation plus
# 3         2022 Jul                                       EBioMedicine
# 4             2022                        Case reports in orthopedics
# ...            ...                                                ...
# 9973          2022                          Frontiers in pharmacology
# 9974   2022 Aug 27  Clinica chimica acta; international journal of...
# 9975          2022                            Frontiers in psychiatry
# 9976   2022 Feb 15                                              eLife
# 9977    2022 Jul 7  Journal of investigative medicine : the offici...
#
#              PMC
# 0            NaN
# 1     PMC8992757
# 2     PMC8844775
# 3     PMC9214799
# 4     PMC9126717
# ...          ...
# 9973  PMC9424766
# 9974         NaN
# 9975  PMC9125182
# 9976  PMC8929929
# 9977         NaN
#
# [9978 rows x 15 columns]

# %% [markdown]
# Here, I isolated the columns that we are going to be utilizing/taken account of. I did not explicitely use the AU column in my function, but I incorporated the formatting that is used in the majority of AU names into my function.

# %%
AU = data2["AU"]
FAU = data2["FAU"]
FAU
# Out:
# 0       Halpenny, Michael;William, Nishaka;Elmoazzen, ...
# 1        Das, Suhasini;Mukherjee, Sukriti;Pathak, Kangkan
# 2       Munot, Sonali;Rugel, Emily J;Von Huben, Amy;Ma...
# 3       Huang, Jian;Law, Evelyn;Karaman, Ibrahim;McCri...
# 4                     Deliwala, Ujjval;Sethia, Sumit Jain
#                               ...
# 9973    Ceccanti, Marco;Libonati, Laura;Ruffolo, Gabri...
# 9974    Bauca, Josep Miquel;Ajzner, Eva;Cadamuro, Jann...
# 9975    Schmitt-Koopmann, Caroline;Baud, Carole-Anne;J...
# 9976    Zhu, Ya-Bing;Wang, Yan;Hua, Xiao-Xiao;Xu, Ling...
# 9977    Verne, Zachary Thomas;Fields, Jeremy Z;Zhang, ...
# Name: FAU, Length: 9978, dtype: object

# %% [markdown]
# Here, I split the columns into seperate names so that I can parse through each individual name

# %%
AU_names = AU.str.split(";")
FAU_names = FAU.str.split(";")
FAU_names
# Out:
# 0       [Halpenny, Michael, William, Nishaka, Elmoazze...
# 1       [Das, Suhasini, Mukherjee, Sukriti, Pathak, Ka...
# 2       [Munot, Sonali, Rugel, Emily J, Von Huben, Amy...
# 3       [Huang, Jian, Law, Evelyn, Karaman, Ibrahim, M...
# 4                  [Deliwala, Ujjval, Sethia, Sumit Jain]
#                               ...
# 9973    [Ceccanti, Marco, Libonati, Laura, Ruffolo, Ga...
# 9974    [Bauca, Josep Miquel, Ajzner, Eva, Cadamuro, J...
# 9975    [Schmitt-Koopmann, Caroline, Baud, Carole-Anne...
# 9976    [Zhu, Ya-Bing, Wang, Yan, Hua, Xiao-Xiao, Xu, ...
# 9977    [Verne, Zachary Thomas, Fields, Jeremy Z, Zhan...
# Name: FAU, Length: 9978, dtype: object

# %% [markdown]
# I iterated through each of the people in each cell and seperated each of them by how many names they have, with a max of 5 names. I created many different variations for the same name. I also made sure that the formatting that was utilized within the AU column was included within my function. I also took into account the names in which there was only one word, as well as those that had a hyphen.

# %%
cumulativeNames = []
for cell in FAU_names:
    cells = []
    for person in cell:
        personNames = []
        splitted = person.split(", ")
        if len(splitted) == 1:
            first_name = full_name[0]
            first_initial =first_name[0]

            personNames.append(first_name) #Elizabeth
            personNames.append(first_initial) #E
            personNames.append(first_initial + ".") #E.
            continue
        fname = splitted[1].split(" ")
        lname = splitted[0].split(" ")
        full_name = fname + lname
        if len(full_name) == 2:
            first_name = full_name[0]
            last_name = full_name[1]

            first_initials = first_name[0]
            last_initials = last_name[0]
            if "-" in first_name:
                first_initials = first_name[0]+first_name[first_name.find("-") + 1]
            if "-" in last_name:
                last_initials = last_name[0]+last_name[last_name.find("-") + 1]
            
            personNames.append(first_name + " " + last_name) #Elizabeth Iskander
            personNames.append(first_name + " " + last_initials) #Elizabeth I
            personNames.append(first_name + " " + last_initials + ".") #Elizabeth I.
            personNames.append(first_initials + last_initials) #EI
            personNames.append(first_initials + "." + last_initials + ".") #E.I.
            personNames.append(first_initials + " " + last_name) #E Iskander
            personNames.append(first_initials + ". " + last_name) #E. Iskander 
            personNames.append(last_name + " " + first_initials) #Iskander E (same format as AU column )
            personNames.append(last_name + " " + first_initials + ".") #Iskander E.
            personNames.append(last_name + ", " + first_name) #Iskander, Elizabeth 
            personNames.append(last_name) #Iskander

        if len(full_name) == 3:
            first_name = full_name[0]
            middle_name = full_name[1]
            last_name = full_name[2]

            first_initials = first_name[0]
            middle_initials = middle_name[0]
            last_initials = last_name[0]
            
            if "-" in first_name:
                first_initials = first_name[0]+first_name[first_name.find("-") + 1]
            if "-" in middle_name:
                middle_initials = middle_name[0]+middle_name[middle_name.find("-") + 1]
            if "-" in last_name:
                last_initials = last_name[0]+last_name[last_name.find("-") + 1]
            
            
            personNames.append(first_name + " " + last_name) #Elizabeth Iskander
            personNames.append(first_name + " " + last_initials) #Elizabeth I
            personNames.append(first_name + " " + last_initials + ".") #Elizabeth I.
            personNames.append(first_name + " " + middle_name + " " + last_name) #Elizabeth Rafik Iskander 
            personNames.append(first_name + " " + middle_initials + last_initials) #Elizabeth RI
            personNames.append(first_name + " " + middle_initials + "." + last_initials + ".") #Elizabeth R.I.
            personNames.append(first_name + " " + middle_initials + " " + last_name) #Elizabeth R Iskander
            personNames.append(first_name + " " + middle_initials + ". " + last_name) #Elizabeth R. Iskander
            personNames.append(first_initials + last_initials) #EI
            personNames.append(first_initials + "." + last_initials + ".") #E.I.
            personNames.append(first_initials + middle_initials + last_initials) #ERI
            personNames.append(first_initials + "." + middle_initials + "." + last_initials + ".") #E.R.I.  
            personNames.append(middle_name + " " + last_name + ", " + first_name) #Rafik Iskander, Elizabeth
            personNames.append(middle_name + " " + last_name + ", " + first_initials) #Rafik Iskander, E
            personNames.append(middle_name + " " + last_name + ", " + first_initials + ".") #Rafik Iskander, E.
            personNames.append(last_name + ", " + first_name + " " + middle_name) #Iskander, Elizabeth Rafik 
            personNames.append(last_name + ", " + first_name + " " + middle_initials) #Iskander, Elizabeth R
            personNames.append(last_name + ", " + first_name + " " + middle_initials + ".") #Iskander, Elizabeth R.
            personNames.append(last_name + " " + first_initials + middle_initials) #Iskander ER (same format as AU column )
            personNames.append(last_name + " " + first_initials + "." + middle_initials + ".") #Iskander E.R. 
            personNames.append(last_name) #Iskander

        if len(full_name) == 4:
            first_name = full_name[0]
            middle1_name = full_name[1]
            middle2_name = full_name[2]
            last_name = full_name[3]

            first_initials = first_name[0]
            middle1_initials = middle1_name[0]
            middle2_initials = middle2_name[0]
            last_initials = last_name[0]
            
            if "-" in first_name:
                first_initials = first_name[0]+first_name[first_name.find("-") + 1]
            if "-" in middle1_name:
                middle1_initials = middle1_name[0]+middle1_name[middle1_name.find("-") + 1]
            if "-" in middle2_name:
                middle2_initials = middle2_name[0]+middle2_name[middle2_name.find("-") + 1]
            if "-" in last_name:
                last_initials = last_name[0]+last_name[last_name.find("-") + 1]

            personNames.append(first_name + " " + last_name) #Elizabeth Iskander
            personNames.append(first_name + " " + last_initials) #Elizabeth I
            personNames.append(first_name + " " + last_initials + ".") #Elizabeth I.
            personNames.append(first_name + " " + middle1_name + " " + last_name) #Elizabeth Rafik Iskander 
            personNames.append(first_name + " " + middle1_name + " " + middle2_name + " " + last_name) #Elizabeth Rafik Sami Iskander
            personNames.append(first_name + " " + middle1_name + " " + middle2_initials + " " + last_name) #Elizabeth Rafik S Iskander
            personNames.append(first_name + " " + middle1_name + " " + middle2_initials + ". " + last_name) #Elizabeth Rafik S. Iskander
            personNames.append(first_name + " " + middle1_initials + last_initials) #Elizabeth RI
            personNames.append(first_name + " " + middle1_initials + "." + last_initials + ".") #Elizabeth R.I.
            personNames.append(first_name + " " + middle1_initials + middle2_initials + last_initials) #Elizabeth RSI
            personNames.append(first_name + " " + middle1_initials + "." + middle2_initials + "." + last_initials + ".") #Elizabeth R.S.I.
            personNames.append(first_name + " " + middle1_initials + " " + last_name) #Elizabeth R Iskander
            personNames.append(first_name + " " + middle1_initials + ". " + last_name) #Elizabeth R. Iskander
            personNames.append(first_name + " " + middle1_initials + middle2_initials + " " + last_name) #Elizabeth RS Iskander
            personNames.append(first_name + " " + middle1_initials + "." + middle2_initials + ". " + last_name) #Elizabeth R.S. Iskander
            personNames.append(first_initials + last_initials) #EI
            personNames.append(first_initials + "." + last_initials + ".") #E.I.
            personNames.append(first_initials + middle1_initials + last_initials) #ERI
            personNames.append(first_initials + "." + middle1_initials + "." + last_initials + ".") #E.R.I
            personNames.append(first_initials + middle1_initials + middle2_initials + last_initials) #ERSI
            personNames.append(first_initials + "." + middle1_initials + "." + middle2_initials + "." + last_initials + ".") #E.R.S.I.
            personNames.append(middle1_name + " " + last_name + ", " + first_name) #Rafik Iskander, Elizabeth
            personNames.append(middle1_name + " " + last_name + ", " + first_initials) #Rafik Iskander, E
            personNames.append(middle1_name + " " + last_name + ", " + first_initials + ".") #Rafik Iskander, E.
            personNames.append(middle1_name + " " + middle2_name + " " + last_name + ", " + first_name) #Rafik Sami Iskander, Elizabeth
            personNames.append(middle1_name + " " + middle2_name + " " + last_name + ", " + first_initials) #Rafik Sami Iskander, E
            personNames.append(middle1_name + " " + middle2_name + " " + last_name + ", " + first_initials + ".") #Rafik Sami Iskander, E.
            personNames.append(last_name + ", " + first_name + " " + middle1_name) #Iskander, Elizabeth Rafik 
            personNames.append(last_name + ", " + first_name + " " + middle1_name + " " + middle2_name) #Iskander, Elizabeth Rafik Sami
            personNames.append(last_name + ", " + first_name + " " + middle1_initials) #Iskander, Elizabeth R
            personNames.append(last_name + ", " + first_name + " " + middle1_initials + ".") #Iskander, Elizabeth R.
            personNames.append(last_name + ", " + first_name + " " + middle1_initials + middle2_initials) #Iskander, Elizabeth RS
            personNames.append(last_name + ", " + first_name + " " + middle1_initials + "." + middle2_initials + ".") #Iskander, Elizabeth R.S.
            personNames.append(last_name + ", " + first_initials) #Iskander, E
            personNames.append(last_name + ", " + first_initials + ".") #Iskander, E.
            personNames.append(last_name + " " + first_initials + middle1_initials) #Iskander ER 
            personNames.append(last_name + " " + first_initials + "." + middle1_initials + ".") #Iskander E.R. 
            personNames.append(last_name + " " + first_initials + middle1_initials + middle2_initials) #Iskander ERS (same format as AU column )
            personNames.append(last_name + " " + first_initials + "." + middle1_initials + "." + middle2_initials + ".") #Iskander E.R.S.
            personNames.append(last_name) #Iskander

        if len(full_name) == 5:
            first_name = full_name[0]
            middle1_name = full_name[1]
            middle2_name = full_name[2]
            middle3_name = full_name[3]
            last_name = full_name[4]

            first_initials = first_name[0]
            middle1_initials = middle1_name[0]
            middle2_initials = middle2_name[0]
            middle3_initials = middle3_name[0]
            last_initials = last_name[0]
            
            if "-" in first_name:
                first_initials = first_name[0]+first_name[first_name.find("-") + 1]
            if "-" in middle1_name:
                middle1_initials = middle1_name[0]+middle1_name[middle1_name.find("-") + 1]
            if "-" in middle2_name:
                middle2_initials = middle2_name[0]+middle2_name[middle2_name.find("-") + 1]
            if "-" in middle2_name:
                middle3_initials = middle3_name[0]+middle3_name[middle3_name.find("-") + 1]
            if "-" in last_name:
                last_initials = last_name[0]+last_name[last_name.find("-") + 1]


            personNames.append(first_name + " " + last_name) #Elizabeth Iskander
            personNames.append(first_name + " " + last_initials) #Elizabeth I
            personNames.append(first_name + " " + last_initials + ".") #Elizabeth I.
            personNames.append(first_name + " " + middle1_name + " " + last_name) #Elizabeth Rafik Iskander 
            personNames.append(first_name + " " + middle1_name + " " + middle2_name + " " + last_name) #Elizabeth Rafik Sami Iskander
            personNames.append(first_name + " " + middle1_name + " " + middle2_name + " " + middle3_name + " " + last_name) #Elizabeth Rafik Sami Mary Iskander
            personNames.append(first_name + " " + middle1_name + " " + middle2_initials + " " + last_name) #Elizabeth Rafik S Iskander
            personNames.append(first_name + " " + middle1_name + " " + middle2_initials + middle3_initials + " " + last_name) #Elizabeth Rafik SM Iskander
            personNames.append(first_name + " " + middle1_name + " " + middle2_initials + ". " + last_name) #Elizabeth Rafik S. Iskander
            personNames.append(first_name + " " + middle1_name + " " + middle2_initials + "." + middle3_initials + ". " + last_name) #Elizabeth Rafik S.M. Iskander
            personNames.append(first_name + " " + middle1_initials + last_initials) #Elizabeth RI
            personNames.append(first_name + " " + middle1_initials + "." + last_initials + ".") #Elizabeth R.I.
            personNames.append(first_name + " " + middle1_initials + middle2_initials + last_initials) #Elizabeth RSI
            personNames.append(first_name + " " + middle1_initials + middle2_initials + middle3_initials +last_initials) #Elizabeth RSMI
            personNames.append(first_name + " " + middle1_initials + "." + middle2_initials + "." + last_initials + ".") #Elizabeth R.S.I.
            personNames.append(first_name + " " + middle1_initials + "." + middle2_initials + "." + middle3_initials + "." +last_initials + ".") #Elizabeth R.S.M.I.
            personNames.append(first_name + " " + middle1_initials + " " + last_name) #Elizabeth R Iskander
            personNames.append(first_name + " " + middle1_initials + ". " + last_name) #Elizabeth R. Iskander
            personNames.append(first_name + " " + middle1_initials + middle2_initials + " " + last_name) #Elizabeth RS Iskander
            personNames.append(first_name + " " + middle1_initials + middle2_initials + middle3_initials + " " + last_name) #Elizabeth RSM Iskander
            personNames.append(first_name + " " + middle1_initials + "." + middle2_initials + ". " + last_name) #Elizabeth R.S. Iskander
            personNames.append(first_name + " " + middle1_initials + "." + middle2_initials + "." + middle3_initials +". " + last_name) #Elizabeth R.S.M. Iskander
            personNames.append(middle1_name + " " + last_name + ", " + first_name) #Rafik Iskander, Elizabeth
            personNames.append(middle1_name + " " + last_name + ", " + first_initials) #Rafik Iskander, E
            personNames.append(middle1_name + " " + last_name + ", " + first_initials + ".") #Rafik Iskander, E.
            personNames.append(middle1_name + " " + middle2_name + " " + last_name + ", " + first_name) #Rafik Sami Iskander, Elizabeth
            personNames.append(middle1_name + " " + middle2_name + " " + last_name + ", " + first_initials) #Rafik Sami Iskander, E
            personNames.append(middle1_name + " " + middle2_name + " " + last_name + ", " + first_initials + ".") #Rafik Sami Iskander, E.
            personNames.append(middle1_name + " " + middle2_name + " " + middle3_name + " " + last_name + ", " + first_name) #Rafik Sami Mary Iskander, Elizabeth
            personNames.append(middle1_name + " " + middle2_name + " " + middle3_name + " " + last_name + ", " + first_initials) #Rafik Sami Mary Iskander, E
            personNames.append(middle1_name + " " + middle2_name + " " + middle3_name + " " + last_name + ", " + first_initials + ".") #Rafik Sami Iskander, E.
            personNames.append(first_initials + last_initials) #EI
            personNames.append(first_initials + "." + last_initials + ".") #E.I.
            personNames.append(first_initials + middle1_initials + last_initials) #ERI
            personNames.append(first_initials + "." + middle1_initials + "." + last_initials) #E.R.I
            personNames.append(first_initials + middle1_initials + middle2_initials + last_initials) #ERSI
            personNames.append(first_initials + "." + middle1_initials + "." + middle2_initials + "." + last_initials) #E.R.S.I.
            personNames.append(first_initials + middle1_initials + middle2_initials + middle3_initials +last_initials) #ERSMI
            personNames.append(first_initials + "." + middle1_initials + "." + middle2_initials + "." + middle3_initials + "." + last_initials + ".") #E.R.S.M.I.
            personNames.append(last_name + ", " + first_name + " " + middle1_name) #Iskander, Elizabeth Rafik 
            personNames.append(last_name + ", " + first_name + " " + middle1_name + " " + middle2_name) #Iskander, Elizabeth Rafik Sami
            personNames.append(last_name + ", " + first_name + " " + middle1_name + " " + middle2_name + " " + middle3_name) #Iskander, Elizabeth Rafik Sami
            personNames.append(last_name + ", " + first_name + " " + middle1_initials) #Iskander, Elizabeth R
            personNames.append(last_name + ", " + first_name + " " + middle1_initials + ".") #Iskander, Elizabeth R.
            personNames.append(last_name + ", " + first_name + " " + middle1_initials + middle2_initials) #Iskander, Elizabeth RS
            personNames.append(last_name + ", " + first_name + " " + middle1_initials + "." + middle2_initials + ".") #Iskander, Elizabeth R.S.
            personNames.append(last_name + ", " + first_name + " " + middle1_initials + middle2_initials + middle3_initials) #Iskander, Elizabeth RSM
            personNames.append(last_name + ", " + first_name + " " + middle1_initials + "." + middle2_initials + "." + middle3_initials + ".") #Iskander, Elizabeth R.S.
            personNames.append(last_name + ", " + first_initials) #Iskander, E
            personNames.append(last_name + ", " + first_initials + ".") #Iskander, E.
            personNames.append(last_name + " " + first_initials + middle1_initials) #Iskander ER 
            personNames.append(last_name + " " + first_initials + "." + middle1_initials + ".") #Iskander E.R. 
            personNames.append(last_name + " " + first_initials + middle1_initials + middle2_initials) #Iskander ERS
            personNames.append(last_name + " " + first_initials + "." + middle1_initials + "." + middle2_initials + ".") #Iskander E.R.S.
            personNames.append(last_name + " " + first_initials + middle1_initials + middle2_initials + middle3_initials) #Iskander ERSM (same format as AU column )
            personNames.append(last_name + " " + first_initials + "." + middle1_initials + "." + middle2_initials + "." + middle3_initials + ".") #Iskander E.R.S.M.
            personNames.append(last_name) #Iskander

        cells.append(personNames)

    cumulativeNames.append(cells)

# %% [markdown]
# Next, I created a new dataframe from the variations that I constructed, and combined the variations for names that are within the same row.

# %%
variations=pd.DataFrame(cumulativeNames)
variations["combined"] = variations.values.tolist()
variations["combined"]
# Out:
# 0       [[Michael Halpenny, Michael H, Michael H., MH,...
# 1       [[Suhasini Das, Suhasini D, Suhasini D., SD, S...
# 2       [[Sonali Munot, Sonali M, Sonali M., SM, S.M.,...
# 3       [[Jian Huang, Jian H, Jian H., JH, J.H., J Hua...
# 4       [[Ujjval Deliwala, Ujjval D, Ujjval D., UD, U....
#                               ...
# 9973    [[Marco Ceccanti, Marco C, Marco C., MC, M.C.,...
# 9974    [[Josep Bauca, Josep B, Josep B., Josep Miquel...
# 9975    [[Caroline Schmitt-Koopmann, Caroline SK, Caro...
# 9976    [[Ya-Bing Zhu, Ya-Bing Z, Ya-Bing Z., YBZ, YB....
# 9977    [[Zachary Verne, Zachary V, Zachary V., Zachar...
# Name: combined, Length: 9978, dtype: object

# %% [markdown]
# Finally, I placed those values into a new column, labeled LAU.

# %%
data2['LAU'] = variations["combined"]
data2
# Out:
#       Unnamed: 0      PMID                                                 TI  \
# 0            NaN  34688545  The importance of evaluating differences in HE...
# 1            NaN  35400747       Syphilis presenting as late-onset psychosis.
# 2            NaN  35199073  Out-of-hospital cardiac arrests and bystander ...
# 3            NaN  35728485  Investigation of metabolomic biomarkers for ch...
# 4            NaN  35615459  Gel-Based Autologous Chondrocyte Implantation ...
# ...          ...       ...                                                ...
# 9973         NaN  36052140  Effects of 3,4-diaminopyridine on myasthenia g...
# 9974         NaN  36041550  An international study on activated partial th...
# 9975         NaN  35615450  Switzerland's Dependence on a Diamorphine Mono...
# 9976         NaN  35167440  PBN-PVT projections modulate negative affectiv...
# 9977         NaN  35798472  Autonomic dysfunction and gastroparesis in Gul...
#
#                                                      AB  \
# 0                                                   NaN
# 1                                                   NaN
# 2     BACKGROUND & AIM: Bystander response to out-of...
# 3     BACKGROUND: Few studies have investigated mole...
# 4     Osteochondritis dissecans (OCD) is a disorder ...
# ...                                                 ...
# 9973  Background: 3,4-diaminopyridine (3,4-DAP) can ...
# 9974  BACKGROUND: Unexpected prolongation of first-l...
# 9975  In 2021, the manufacturer of diamorphine repor...
# 9976  Long-lasting negative affections dampen enthus...
# 9977  Over 25% of veterans with Gulf War illness dev...
#
#                                                      AD  \
# 0     Canadian Blood Services, Ottawa, Ontario, Cana...
# 1     Department of Psychiatry, Lokopriya Gopinath B...
# 2     Westmead Applied Research Centre, Faculty of M...
# 3     Singapore Institute for Clinical Sciences (SIC...
# 4     Deliwala Arthroscopy & Sports Injury Center, B...
# ...                                                 ...
# 9973  Neuromuscular Disorders Unit, Department of Hu...
# 9974  Department of Laboratory Medicine, Hospital Un...
# 9975  Service of Addiction Medicine, Lausanne Univer...
# 9976  Department of Anesthesiology, Shanghai General...
# 9977  Biology, Texas A&M University System, College ...
#
#                                                     AID  \
# 0     S1465-3249(21)00786-6 [pii];10.1016/j.jcyt.202...
# 1     10.4103/indianjpsychiatry.indianjpsychiatry_31...
# 2     10.1016/j.resplu.2022.100205 [doi];S2666-5204(...
# 3     S2352-3964(22)00292-4 [pii];10.1016/j.ebiom.20...
# 4                            10.1155/2022/6946860 [doi]
# ...                                                 ...
# 9973       10.3389/fphar.2022.982434 [doi];982434 [pii]
# 9974  S0009-8981(22)01282-7 [pii];10.1016/j.cca.2022...
# 9975                    10.3389/fpsyt.2022.882299 [doi]
# 9976              10.7554/eLife.68372 [doi];68372 [pii]
# 9977  jim-2021-002291 [pii];10.1136/jim-2021-002291 ...
#
#                                                      AU  \
# 0     Halpenny M;William N;Elmoazzen H;Giulivi A;Mar...
# 1                            Das S;Mukherjee S;Pathak K
# 2     Munot S;Rugel EJ;Von Huben A;Marschner S;Redfe...
# 3     Huang J;Law E;Karaman I;McCrickerd K;Fogel A;C...
# 4                                  Deliwala U;Sethia SJ
# ...                                                 ...
# 9973  Ceccanti M;Libonati L;Ruffolo G;Cifelli P;More...
# 9974  Bauca JM;Ajzner E;Cadamuro J;Hillarp A;Kristof...
# 9975         Schmitt-Koopmann C;Baud CA;Junod V;Simon O
# 9976  Zhu YB;Wang Y;Hua XX;Xu L;Liu MZ;Zhang R;Liu P...
# 9977                 Verne ZT;Fields JZ;Zhang BB;Zhou Q
#
#                                                    AUID  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4          ORCID: https://orcid.org/0000-0003-1226-4380
# ...                                                 ...
# 9973                                                NaN
# 9974                                                NaN
# 9975                                                NaN
# 9976  ORCID: https://orcid.org/0000-0002-8308-6553;O...
# 9977        ORCID: http://orcid.org/0000-0003-4165-6404
#
#                                                     FAU  \
# 0     Halpenny, Michael;William, Nishaka;Elmoazzen, ...
# 1      Das, Suhasini;Mukherjee, Sukriti;Pathak, Kangkan
# 2     Munot, Sonali;Rugel, Emily J;Von Huben, Amy;Ma...
# 3     Huang, Jian;Law, Evelyn;Karaman, Ibrahim;McCri...
# 4                   Deliwala, Ujjval;Sethia, Sumit Jain
# ...                                                 ...
# 9973  Ceccanti, Marco;Libonati, Laura;Ruffolo, Gabri...
# 9974  Bauca, Josep Miquel;Ajzner, Eva;Cadamuro, Jann...
# 9975  Schmitt-Koopmann, Caroline;Baud, Carole-Anne;J...
# 9976  Zhu, Ya-Bing;Wang, Yan;Hua, Xiao-Xiao;Xu, Ling...
# 9977  Verne, Zachary Thomas;Fields, Jeremy Z;Zhang, ...
#
#      Does COIS include a conflict? (0=no conflict, 1=conflict)  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 9973                                                NaN
# 9974                                                NaN
# 9975                                                NaN
# 9976                                                NaN
# 9977                                                NaN
#
#                                                    COIS         DEP  \
# 0     Declaration of Competing Interest The authors ...  20211028.0
# 1                   There are no conflicts of interest.  20220121.0
# 2     The authors declare that they have no known co...  20220206.0
# 3     Declaration of interests The authors disclose ...  20220618.0
# 4     The authors declare no conflict of interest fo...  20220516.0
# ...                                                 ...         ...
# 9973  The authors declare that the research was cond...  20220816.0
# 9974  Declaration of Competing Interest The authors ...  20220827.0
# 9975  The authors declare that the research was cond...  20220509.0
# 9976  YZ, YW, XH, LX, ML, RZ, PL, JL, LZ, DM No comp...  20220215.0
# 9977                Competing interests: None declared.  20220707.0
#
#                 DP                                                 JT  \
# 0         2022 Mar                                        Cytotherapy
# 1     2022 Jan-Feb                       Indian journal of psychiatry
# 2         2022 Mar                                 Resuscitation plus
# 3         2022 Jul                                       EBioMedicine
# 4             2022                        Case reports in orthopedics
# ...            ...                                                ...
# 9973          2022                          Frontiers in pharmacology
# 9974   2022 Aug 27  Clinica chimica acta; international journal of...
# 9975          2022                            Frontiers in psychiatry
# 9976   2022 Feb 15                                              eLife
# 9977    2022 Jul 7  Journal of investigative medicine : the offici...
#
#              PMC                                                LAU
# 0            NaN  [[Michael Halpenny, Michael H, Michael H., MH,...
# 1     PMC8992757  [[Suhasini Das, Suhasini D, Suhasini D., SD, S...
# 2     PMC8844775  [[Sonali Munot, Sonali M, Sonali M., SM, S.M.,...
# 3     PMC9214799  [[Jian Huang, Jian H, Jian H., JH, J.H., J Hua...
# 4     PMC9126717  [[Ujjval Deliwala, Ujjval D, Ujjval D., UD, U....
# ...          ...                                                ...
# 9973  PMC9424766  [[Marco Ceccanti, Marco C, Marco C., MC, M.C.,...
# 9974         NaN  [[Josep Bauca, Josep B, Josep B., Josep Miquel...
# 9975  PMC9125182  [[Caroline Schmitt-Koopmann, Caroline SK, Caro...
# 9976  PMC8929929  [[Ya-Bing Zhu, Ya-Bing Z, Ya-Bing Z., YBZ, YB....
# 9977         NaN  [[Zachary Verne, Zachary V, Zachary V., Zachar...
#
# [9978 rows x 16 columns]
